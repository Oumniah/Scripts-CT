# %%
import pandas as pd

#files 2021
    
columns = ['0','date','v_dtt_qte_support','v_dtt_qte_charge','v_dtt_ab_hebdo','v_dtt_ab_mens',\
                                            'v_dtt_ab_mens_etud','v_agence_support_b','v_agence_support_c','v_agence_voyage',\
                                            'v_agence_ab_hebdo','v_agence_ab_mens',\
                                            'v_agence_ab_mens_etud','v_depo_support_b','v_depo_support_c','v_depo_voyage',\
                                            'v_depo_ab_hebdo','v_depo_ab_mens','v_depo_ab_mens_etud',\
                                            'v_pv_support_b','v_pv_voyage',\
                                            'ca_dtt_support','ca_dtt_charge','ca_dtt_ab_hebdo','ca_dtt_ab_mens',\
                                            'ca_dtt_ab_mens_etud','ca_dtt_banque',\
                                            'ca_agence_support_b','ca_agence_support_c','ca_agence_voyage',\
                                            'ca_agence_ab_hebdo','ca_agence_ab_mens',\
                                            'ca_agence_ab_mens_etud','ca_agence_banque',\
                                            'ca_depo_support_b','ca_depo_support_c','ca_depo_voyage',\
                                            'ca_depo_ab_hebdo','ca_depo_ab_mens','ca_depo_ab_mens_etud',\
                                            'ca_pv_support_b','ca_pv_voyage','rembours_banque','total']

v_columns = ['v_dtt_qte_support','v_dtt_qte_charge','v_dtt_ab_hebdo','v_dtt_ab_mens',\
                                            'v_dtt_ab_mens_etud','v_agence_support_b','v_agence_support_c','v_agence_voyage',\
                                            'v_agence_ab_hebdo','v_agence_ab_mens',\
                                            'v_agence_ab_mens_etud','v_depo_support_b','v_depo_support_c','v_depo_voyage',\
                                            'v_depo_ab_hebdo','v_depo_ab_mens','v_depo_ab_mens_etud',\
                                            'v_pv_support_b','v_pv_voyage']
ca_columns = ['ca_dtt_support','ca_dtt_charge','ca_dtt_ab_hebdo','ca_dtt_ab_mens',\
                                            'ca_dtt_ab_mens_etud','ca_agence_support_b','ca_agence_support_c','ca_agence_voyage',\
                                            'ca_agence_ab_hebdo','ca_agence_ab_mens',\
                                            'ca_agence_ab_mens_etud',\
                                            'ca_depo_support_b','ca_depo_support_c','ca_depo_voyage',\
                                            'ca_depo_ab_hebdo','ca_depo_ab_mens','ca_depo_ab_mens_etud',\
                                            'ca_pv_support_b','ca_pv_voyage']


#get the file
file = "Consolidation H des recettes Transport du 30 12 2020 au 05 01 2021.xlsx"
data = pd.read_excel(file, header=11,names=columns, dtype={'date' : str}) 


#lists initialization
e_dtt_support = []
e_dtt_charge = []
e_dtt_ab_hebdo = []
e_dtt_ab_mens = []
e_dtt_ab_mens_etud = []
e_agence_support_b = []
e_agence_support_c = []
e_agence_voyage = []
e_agence_ab_hebdo = []
e_agence_ab_mens = []
e_agence_ab_mens_etud = []
e_depo_support_b = []
e_depo_support_c = []
e_depo_voyage = []
e_depo_ab_hebdo = []
e_depo_ab_mens = []
e_depo_ab_mens_etud = []
e_pv_support_b = []
e_pv_voyage = []
#gabs calculation

e_dtt_support = data[ca_columns[0]] - (data[v_columns[0]]*2)
e_dtt_charge = data[ca_columns[1]] - (data[v_columns[1]]*6)
e_dtt_ab_hebdo = data[ca_columns[2]] - (data[v_columns[2]]*60)
e_dtt_ab_mens = data[ca_columns[3]] - (data[v_columns[3]]*230)
e_dtt_ab_mens_etud = data[ca_columns[4]] - (data[v_columns[4]]*150)
e_agence_support_b = data[ca_columns[5]] - (data[v_columns[5]]*2)
e_agence_support_c = data[ca_columns[6]] - (data[v_columns[6]]*15)
e_agence_voyage = data[ca_columns[7]] - (data[v_columns[7]]*6)
e_agence_ab_hebdo = data[ca_columns[8]] - (data[v_columns[8]]*60)
e_agence_ab_mens = data[ca_columns[9]] - (data[v_columns[9]]*230)
e_agence_ab_mens_etud = data[ca_columns[10]] - (data[v_columns[10]]*150)
e_depo_support_b = data[ca_columns[11]] - (data[v_columns[11]]*2)
e_depo_support_c = data[ca_columns[12]] - (data[v_columns[12]]*15)
e_depo_voyage = data[ca_columns[13]] - (data[v_columns[13]]*6)
e_depo_ab_hebdo = data[ca_columns[14]] - (data[v_columns[14]]*60)
e_depo_ab_mens = data[ca_columns[15]] - (data[v_columns[15]]*230)
e_depo_ab_mens_etud = data[ca_columns[16]] - (data[v_columns[16]]*150)
e_pv_support_b = data[ca_columns[17]] - (data[v_columns[17]]*2)
e_pv_voyage = data[ca_columns[18]] - (data[v_columns[18]]*6)

#dataframe making

d = {
    'Date' : data['date'],
    'Dtt Ecart support' : e_dtt_support,
    'Dtt chargement' : e_dtt_charge,
    'Dtt Ecart Ab Hebdo' : e_dtt_ab_hebdo,
    'Dtt Ecart Ab Mens' : e_dtt_ab_mens,
    'Dtt Ecart Ab Mens Etud' : e_dtt_ab_mens_etud,
    'Agence Ecart support BSC' : e_agence_support_b,
    'Agence Ecart support CSC' : e_agence_support_c,
    'Agence Ecart voyage' : e_agence_voyage,
    'Agence Ecart Ab Hebdo' : e_agence_ab_hebdo,
    'Agence Ecart Ab Mens' : e_agence_ab_mens,
    'Agence Ecart Ab Mens Etud' : e_agence_ab_mens_etud,
    'Depo Ecart support BSC' : e_depo_support_b,
    'Depo Ecart support CSC' : e_depo_support_c,
    'Depo Ecart voyage' : e_depo_voyage,
    'Depo Ecart Ab Hebdo' : e_depo_ab_hebdo,
    'Depo Ecart Mens' : e_depo_ab_mens,
    'Depo Ecart Mens Etud' : e_depo_ab_mens_etud,
    'PV Ecart support BSC' : e_pv_support_b,
    'PV Ecart support voyage' : e_pv_voyage
}

#file generation
result = pd.DataFrame(data = d)
result.to_excel('Ecarts 2021.xlsx',index=False,)
print("file generated !")
# Out:
# file generated !

# %%
import pandas as pd

#files 2020
    
columns = ['date','v_dtt_qte_support','v_dtt_qte_charge','v_dtt_ab_hebdo','v_dtt_ab_mens',\
                                            'v_dtt_ab_mens_etud','v_agence_support_b','v_agence_support_c','v_agence_voyage',\
                                            'v_agence_ab_hebdo','v_agence_ab_mens',\
                                            'v_agence_ab_mens_etud','v_depo_support_b','v_depo_support_c','v_depo_voyage',\
                                            'v_depo_ab_hebdo','v_depo_ab_mens','v_depo_ab_mens_etud',\
                                            'v_pv_support_b','v_pv_voyage',\
                                            'ca_dtt_support','ca_dtt_charge','ca_dtt_ab_hebdo','ca_dtt_ab_mens',\
                                            'ca_dtt_ab_mens_etud','ca_dtt_banque',\
                                            'ca_agence_support_b','ca_agence_support_c','ca_agence_voyage',\
                                            'ca_agence_ab_hebdo','ca_agence_ab_mens',\
                                            'ca_agence_ab_mens_etud','ca_agence_banque',\
                                            'ca_depo_support_b','ca_depo_support_c','ca_depo_voyage',\
                                            'ca_depo_ab_hebdo','ca_depo_ab_mens','ca_depo_ab_mens_etud',\
                                            'ca_pv_support_b','ca_pv_voyage','total']

v_columns = ['v_dtt_qte_support','v_dtt_qte_charge','v_dtt_ab_hebdo','v_dtt_ab_mens',\
                                            'v_dtt_ab_mens_etud','v_agence_support_b','v_agence_support_c','v_agence_voyage',\
                                            'v_agence_ab_hebdo','v_agence_ab_mens',\
                                            'v_agence_ab_mens_etud','v_depo_support_b','v_depo_support_c','v_depo_voyage',\
                                            'v_depo_ab_hebdo','v_depo_ab_mens','v_depo_ab_mens_etud',\
                                            'v_pv_support_b','v_pv_voyage']
ca_columns = ['ca_dtt_support','ca_dtt_charge','ca_dtt_ab_hebdo','ca_dtt_ab_mens',\
                                            'ca_dtt_ab_mens_etud','ca_agence_support_b','ca_agence_support_c','ca_agence_voyage',\
                                            'ca_agence_ab_hebdo','ca_agence_ab_mens',\
                                            'ca_agence_ab_mens_etud',\
                                            'ca_depo_support_b','ca_depo_support_c','ca_depo_voyage',\
                                            'ca_depo_ab_hebdo','ca_depo_ab_mens','ca_depo_ab_mens_etud',\
                                            'ca_pv_support_b','ca_pv_voyage']


#get the file
file = "42-Consolidation des recettes Transport du 30 09 2020 au 06 10 2020.xlsx"
data = pd.read_excel(file, header=11,names=columns, dtype={'date' : str}) 


print(data)
#lists initialization
e_dtt_support = []
e_dtt_charge = []
e_dtt_ab_hebdo = []
e_dtt_ab_mens = []
e_dtt_ab_mens_etud = []
e_agence_support_b = []
e_agence_support_c = []
e_agence_voyage = []
e_agence_ab_hebdo = []
e_agence_ab_mens = []
e_agence_ab_mens_etud = []
e_depo_support_b = []
e_depo_support_c = []
e_depo_voyage = []
e_depo_ab_hebdo = []
e_depo_ab_mens = []
e_depo_ab_mens_etud = []
e_pv_support_b = []
e_pv_voyage = []
#gabs calculation

e_dtt_support = data[ca_columns[0]] - (data[v_columns[0]]*2)
e_dtt_charge = data[ca_columns[1]] - (data[v_columns[1]]*6)
e_dtt_ab_hebdo = data[ca_columns[2]] - (data[v_columns[2]]*60)
e_dtt_ab_mens = data[ca_columns[3]] - (data[v_columns[3]]*230)
e_dtt_ab_mens_etud = data[ca_columns[4]] - (data[v_columns[4]]*150)
e_agence_support_b = data[ca_columns[5]] - (data[v_columns[5]]*2)
e_agence_support_c = data[ca_columns[6]] - (data[v_columns[6]]*15)
e_agence_voyage = data[ca_columns[7]] - (data[v_columns[7]]*6)
e_agence_ab_hebdo = data[ca_columns[8]] - (data[v_columns[8]]*60)
e_agence_ab_mens = data[ca_columns[9]] - (data[v_columns[9]]*230)
e_agence_ab_mens_etud = data[ca_columns[10]] - (data[v_columns[10]]*150)
e_depo_support_b = data[ca_columns[11]] - (data[v_columns[11]]*2)
e_depo_support_c = data[ca_columns[12]] - (data[v_columns[12]]*15)
e_depo_voyage = data[ca_columns[13]] - (data[v_columns[13]]*6)
e_depo_ab_hebdo = data[ca_columns[14]] - (data[v_columns[14]]*60)
e_depo_ab_mens = data[ca_columns[15]] - (data[v_columns[15]]*230)
e_depo_ab_mens_etud = data[ca_columns[16]] - (data[v_columns[16]]*150)
e_pv_support_b = data[ca_columns[17]] - (data[v_columns[17]]*2)
e_pv_voyage = data[ca_columns[18]] - (data[v_columns[18]]*6)

#dataframe making

d = {
    'Date' : data['date'],
    'Dtt Ecart support' : e_dtt_support,
    'Dtt chargement' : e_dtt_charge,
    'Dtt Ecart Ab Hebdo' : e_dtt_ab_hebdo,
    'Dtt Ecart Ab Mens' : e_dtt_ab_mens,
    'Dtt Ecart Ab Mens Etud' : e_dtt_ab_mens_etud,
    'Agence Ecart support BSC' : e_agence_support_b,
    'Agence Ecart support CSC' : e_agence_support_c,
    'Agence Ecart voyage' : e_agence_voyage,
    'Agence Ecart Ab Hebdo' : e_agence_ab_hebdo,
    'Agence Ecart Ab Mens' : e_agence_ab_mens,
    'Agence Ecart Ab Mens Etud' : e_agence_ab_mens_etud,
    'Depo Ecart support BSC' : e_depo_support_b,
    'Depo Ecart support CSC' : e_depo_support_c,
    'Depo Ecart voyage' : e_depo_voyage,
    'Depo Ecart Ab Hebdo' : e_depo_ab_hebdo,
    'Depo Ecart Mens' : e_depo_ab_mens,
    'Depo Ecart Mens Etud' : e_depo_ab_mens_etud,
    'PV Ecart support BSC' : e_pv_support_b,
    'PV Ecart support voyage' : e_pv_voyage
}

#file generation
result = pd.DataFrame(data = d)
result.to_excel('Ecarts du 30 09 2020 au 06 10 2020.xlsx',index=False)
print("file generated !")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-164-f8759d049b4b> in <module>
#      35 #get the file
#      36 file = "42-Consolidation des recettes Transport du 30 09 2020 au 06 10 2020.xlsx"
# ---> 37 data = pd.read_excel(file, header=11,names=columns, dtype={'date' : str})
#      38
#      39
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     309         )
#     310
# --> 311     return io.parse(
#     312         sheet_name=sheet_name,
#     313         header=header,
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in parse(self, sheet_name, header, names, index_col, usecols, squeeze, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     904             DataFrame from the passed in Excel file.
#     905         """
# --> 906         return self._reader.parse(
#     907             sheet_name=sheet_name,
#     908             header=header,
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in parse(self, sheet_name, header, names, index_col, usecols, squeeze, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     492             # GH 12292 : error when read one empty column from excel file
#     493             try:
# --> 494                 parser = TextParser(
#     495                     data,
#     496                     names=names,
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in TextParser(*args, **kwds)
#    2317     """
#    2318     kwds["engine"] = "python"
# -> 2319     return TextFileReader(*args, **kwds)
#    2320
#    2321
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1187                     'are "c", "python", or "python-fwf")'
#    1188                 )
# -> 1189             self._engine = klass(self.f, **self.options)
#    1190
#    1191     def _failover_to_python(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, **kwds)
#    2403                 self.num_original_columns,
#    2404                 self.unnamed_cols,
# -> 2405             ) = self._infer_columns()
#    2406         except (TypeError, ValueError):
#    2407             self.close()
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _infer_columns(self)
#    2763                     self.usecols is None and len(names) != len(columns[0])
#    2764                 ):
# -> 2765                     raise ValueError(
#    2766                         "Number of passed names did not match "
#    2767                         "number of header fields in the file"
#
# ValueError: Number of passed names did not match number of header fields in the file

# %%
import pandas as pd

#files 2020 - 09,10,11,12,16,18,20,21,22,23,24,25,26,27...42
    
columns = ['date','v_dtt_qte_support','v_dtt_qte_charge','v_dtt_ab_hebdo','v_dtt_ab_mens',\
                                            'v_dtt_ab_mens_etud','v_agence_support_b','v_agence_support_c','v_agence_voyage',\
                                            'v_agence_ab_hebdo','v_agence_ab_mens',\
                                            'v_agence_ab_mens_etud','v_depo_support_b','v_depo_support_c','v_depo_voyage',\
                                            'v_depo_ab_hebdo','v_depo_ab_mens','v_depo_ab_mens_etud',\
                                            'v_pv_support_b','v_pv_voyage',\
                                            'ca_dtt_support','ca_dtt_charge','ca_dtt_ab_hebdo','ca_dtt_ab_mens',\
                                            'ca_dtt_ab_mens_etud','ca_dtt_banque',\
                                            'ca_agence_support_b','ca_agence_support_c','ca_agence_voyage',\
                                            'ca_agence_ab_hebdo','ca_agence_ab_mens',\
                                            'ca_agence_ab_mens_etud','ca_agence_banque',\
                                            'ca_depo_support_b','ca_depo_support_c','ca_depo_voyage',\
                                            'ca_depo_ab_hebdo','ca_depo_ab_mens','ca_depo_ab_mens_etud',\
                                            'ca_pv_support_b','ca_pv_voyage','total']

v_columns = ['v_dtt_qte_support','v_dtt_qte_charge','v_dtt_ab_hebdo','v_dtt_ab_mens',\
                                            'v_dtt_ab_mens_etud','v_agence_support_b','v_agence_support_c','v_agence_voyage',\
                                            'v_agence_ab_hebdo','v_agence_ab_mens',\
                                            'v_agence_ab_mens_etud','v_depo_support_b','v_depo_support_c','v_depo_voyage',\
                                            'v_depo_ab_hebdo','v_depo_ab_mens','v_depo_ab_mens_etud',\
                                            'v_pv_support_b','v_pv_voyage']
ca_columns = ['ca_dtt_support','ca_dtt_charge','ca_dtt_ab_hebdo','ca_dtt_ab_mens',\
                                            'ca_dtt_ab_mens_etud','ca_agence_support_b','ca_agence_support_c','ca_agence_voyage',\
                                            'ca_agence_ab_hebdo','ca_agence_ab_mens',\
                                            'ca_agence_ab_mens_etud',\
                                            'ca_depo_support_b','ca_depo_support_c','ca_depo_voyage',\
                                            'ca_depo_ab_hebdo','ca_depo_ab_mens','ca_depo_ab_mens_etud',\
                                            'ca_pv_support_b','ca_pv_voyage']


#get the file
file = "22-Consolidation des recettes Transport du 02 12 2020 au 08 12 2020.xlsx"
data = pd.read_excel(file, header=11,names=columns, dtype={'date' : str}) 


#lists initialization
e_dtt_support = []
e_dtt_charge = []
e_dtt_ab_hebdo = []
e_dtt_ab_mens = []
e_dtt_ab_mens_etud = []
e_agence_support_b = []
e_agence_support_c = []
e_agence_voyage = []
e_agence_ab_hebdo = []
e_agence_ab_mens = []
e_agence_ab_mens_etud = []
e_depo_support_b = []
e_depo_support_c = []
e_depo_voyage = []
e_depo_ab_hebdo = []
e_depo_ab_mens = []
e_depo_ab_mens_etud = []
e_pv_support_b = []
e_pv_voyage = []
#gabs calculation

e_dtt_support = data[ca_columns[0]] - (data[v_columns[0]]*2)
e_dtt_charge = data[ca_columns[1]] - (data[v_columns[1]]*6)
e_dtt_ab_hebdo = data[ca_columns[2]] - (data[v_columns[2]]*60)
e_dtt_ab_mens = data[ca_columns[3]] - (data[v_columns[3]]*230)
e_dtt_ab_mens_etud = data[ca_columns[4]] - (data[v_columns[4]]*150)
e_agence_support_b = data[ca_columns[5]] - (data[v_columns[5]]*2)
e_agence_support_c = data[ca_columns[6]] - (data[v_columns[6]]*15)
e_agence_voyage = data[ca_columns[7]] - (data[v_columns[7]]*6)
e_agence_ab_hebdo = data[ca_columns[8]] - (data[v_columns[8]]*60)
e_agence_ab_mens = data[ca_columns[9]] - (data[v_columns[9]]*230)
e_agence_ab_mens_etud = data[ca_columns[10]] - (data[v_columns[10]]*150)
e_depo_support_b = data[ca_columns[11]] - (data[v_columns[11]]*2)
e_depo_support_c = data[ca_columns[12]] - (data[v_columns[12]]*15)
e_depo_voyage = data[ca_columns[13]] - (data[v_columns[13]]*6)
e_depo_ab_hebdo = data[ca_columns[14]] - (data[v_columns[14]]*60)
e_depo_ab_mens = data[ca_columns[15]] - (data[v_columns[15]]*230)
e_depo_ab_mens_etud = data[ca_columns[16]] - (data[v_columns[16]]*150)
e_pv_support_b = data[ca_columns[17]] - (data[v_columns[17]]*2)
e_pv_voyage = data[ca_columns[18]] - (data[v_columns[18]]*6)

#dataframe making

d = {
    'Date' : data['date'],
    'Dtt Ecart support' : e_dtt_support,
    'Dtt chargement' : e_dtt_charge,
    'Dtt Ecart Ab Hebdo' : e_dtt_ab_hebdo,
    'Dtt Ecart Ab Mens' : e_dtt_ab_mens,
    'Dtt Ecart Ab Mens Etud' : e_dtt_ab_mens_etud,
    'Agence Ecart support BSC' : e_agence_support_b,
    'Agence Ecart support CSC' : e_agence_support_c,
    'Agence Ecart voyage' : e_agence_voyage,
    'Agence Ecart Ab Hebdo' : e_agence_ab_hebdo,
    'Agence Ecart Ab Mens' : e_agence_ab_mens,
    'Agence Ecart Ab Mens Etud' : e_agence_ab_mens_etud,
    'Depo Ecart support BSC' : e_depo_support_b,
    'Depo Ecart support CSC' : e_depo_support_c,
    'Depo Ecart voyage' : e_depo_voyage,
    'Depo Ecart Ab Hebdo' : e_depo_ab_hebdo,
    'Depo Ecart Mens' : e_depo_ab_mens,
    'Depo Ecart Mens Etud' : e_depo_ab_mens_etud,
    'PV Ecart support BSC' : e_pv_support_b,
    'PV Ecart support voyage' : e_pv_voyage
}

#file generation
result = pd.DataFrame(data = d)
result.to_excel('Ecarts du 02 12 2020 au 08 12 2020.xlsx',index=False,)
print("file generated !")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-be9c10fc16af> in <module>
#      35 #get the file
#      36 file = "22-Consolidation des recettes Transport du 02 12 2020 au 08 12 2020.xlsx"
# ---> 37 data = pd.read_excel(file, header=11,names=columns, dtype={'date' : str})
#      38
#      39
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     309         )
#     310
# --> 311     return io.parse(
#     312         sheet_name=sheet_name,
#     313         header=header,
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in parse(self, sheet_name, header, names, index_col, usecols, squeeze, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     904             DataFrame from the passed in Excel file.
#     905         """
# --> 906         return self._reader.parse(
#     907             sheet_name=sheet_name,
#     908             header=header,
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in parse(self, sheet_name, header, names, index_col, usecols, squeeze, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     492             # GH 12292 : error when read one empty column from excel file
#     493             try:
# --> 494                 parser = TextParser(
#     495                     data,
#     496                     names=names,
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in TextParser(*args, **kwds)
#    2317     """
#    2318     kwds["engine"] = "python"
# -> 2319     return TextFileReader(*args, **kwds)
#    2320
#    2321
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1187                     'are "c", "python", or "python-fwf")'
#    1188                 )
# -> 1189             self._engine = klass(self.f, **self.options)
#    1190
#    1191     def _failover_to_python(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, **kwds)
#    2403                 self.num_original_columns,
#    2404                 self.unnamed_cols,
# -> 2405             ) = self._infer_columns()
#    2406         except (TypeError, ValueError):
#    2407             self.close()
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _infer_columns(self)
#    2763                     self.usecols is None and len(names) != len(columns[0])
#    2764                 ):
# -> 2765                     raise ValueError(
#    2766                         "Number of passed names did not match "
#    2767                         "number of header fields in the file"
#
# ValueError: Number of passed names did not match number of header fields in the file

# %%
import pandas as pd

#files 2020 - 09,10,11,12,16,18,20
columns = ['date','v_dtt_qte_support','v_dtt_qte_charge','v_dtt_ab_hebdo','v_dtt_ab_mens',\
                                            'v_dtt_ab_mens_etud','v_agence_support_b','v_agence_support_c','v_agence_voyage',\
                                            'v_agence_ab_hebdo','v_agence_ab_mens',\
                                            'v_agence_ab_mens_etud','v_depo_support_b','v_depo_support_c','v_depo_voyage',\
                                            'v_depo_ab_hebdo','v_depo_ab_mens','v_depo_ab_mens_etud',\
                                            'v_pv_support_b','v_pv_voyage',\
                                            'ca_dtt_support','ca_dtt_charge','ca_dtt_ab_hebdo','ca_dtt_ab_mens',\
                                            'ca_dtt_ab_mens_etud','ca_dtt_banque',\
                                            'ca_agence_support_b','ca_agence_support_c','ca_agence_voyage',\
                                            'ca_agence_ab_hebdo','ca_agence_ab_mens',\
                                            'ca_agence_ab_mens_etud','ca_agence_banque',\
                                            'ca_depo_support_b','ca_depo_support_c','ca_depo_voyage',\
                                            'ca_depo_ab_hebdo','ca_depo_ab_mens','ca_depo_ab_mens_etud',\
                                            'ca_pv_support_b','ca_pv_voyage','total','#']

v_columns = ['v_dtt_qte_support','v_dtt_qte_charge','v_dtt_ab_hebdo','v_dtt_ab_mens',\
                                            'v_dtt_ab_mens_etud','v_agence_support_b','v_agence_support_c','v_agence_voyage',\
                                            'v_agence_ab_hebdo','v_agence_ab_mens',\
                                            'v_agence_ab_mens_etud','v_depo_support_b','v_depo_support_c','v_depo_voyage',\
                                            'v_depo_ab_hebdo','v_depo_ab_mens','v_depo_ab_mens_etud',\
                                            'v_pv_support_b','v_pv_voyage']
ca_columns = ['ca_dtt_support','ca_dtt_charge','ca_dtt_ab_hebdo','ca_dtt_ab_mens',\
                                            'ca_dtt_ab_mens_etud','ca_agence_support_b','ca_agence_support_c','ca_agence_voyage',\
                                            'ca_agence_ab_hebdo','ca_agence_ab_mens',\
                                            'ca_agence_ab_mens_etud',\
                                            'ca_depo_support_b','ca_depo_support_c','ca_depo_voyage',\
                                            'ca_depo_ab_hebdo','ca_depo_ab_mens','ca_depo_ab_mens_etud',\
                                            'ca_pv_support_b','ca_pv_voyage']


#get the file
file = "09-Consolidation recette transport du 04 au 10 Mars 2020.xlsx"
#data = pd.read_excel(file, header=11,names=columns, dtype={'date' : str}) 
data = pd.read_excel(file, header=11) 
print(data.columns)

#lists initialization
e_dtt_support = []
e_dtt_charge = []
e_dtt_ab_hebdo = []
e_dtt_ab_mens = []
e_dtt_ab_mens_etud = []
e_agence_support_b = []
e_agence_support_c = []
e_agence_voyage = []
e_agence_ab_hebdo = []
e_agence_ab_mens = []
e_agence_ab_mens_etud = []
e_depo_support_b = []
e_depo_support_c = []
e_depo_voyage = []
e_depo_ab_hebdo = []
e_depo_ab_mens = []
e_depo_ab_mens_etud = []
e_pv_support_b = []
e_pv_voyage = []
#gabs calculation

e_dtt_support = data[ca_columns[0]] - (data[v_columns[0]]*2)
e_dtt_charge = data[ca_columns[1]] - (data[v_columns[1]]*6)
e_dtt_ab_hebdo = data[ca_columns[2]] - (data[v_columns[2]]*60)
e_dtt_ab_mens = data[ca_columns[3]] - (data[v_columns[3]]*230)
e_dtt_ab_mens_etud = data[ca_columns[4]] - (data[v_columns[4]]*150)
e_agence_support_b = data[ca_columns[5]] - (data[v_columns[5]]*2)
e_agence_support_c = data[ca_columns[6]] - (data[v_columns[6]]*15)
e_agence_voyage = data[ca_columns[7]] - (data[v_columns[7]]*6)
e_agence_ab_hebdo = data[ca_columns[8]] - (data[v_columns[8]]*60)
e_agence_ab_mens = data[ca_columns[9]] - (data[v_columns[9]]*230)
e_agence_ab_mens_etud = data[ca_columns[10]] - (data[v_columns[10]]*150)
e_depo_support_b = data[ca_columns[11]] - (data[v_columns[11]]*2)
e_depo_support_c = data[ca_columns[12]] - (data[v_columns[12]]*15)
e_depo_voyage = data[ca_columns[13]] - (data[v_columns[13]]*6)
e_depo_ab_hebdo = data[ca_columns[14]] - (data[v_columns[14]]*60)
e_depo_ab_mens = data[ca_columns[15]] - (data[v_columns[15]]*230)
e_depo_ab_mens_etud = data[ca_columns[16]] - (data[v_columns[16]]*150)
e_pv_support_b = data[ca_columns[17]] - (data[v_columns[17]]*2)
e_pv_voyage = data[ca_columns[18]] - (data[v_columns[18]]*6)

#dataframe making

d = {
    'Date' : data['date'],
    'Dtt Ecart support' : e_dtt_support,
    'Dtt chargement' : e_dtt_charge,
    'Dtt Ecart Ab Hebdo' : e_dtt_ab_hebdo,
    'Dtt Ecart Ab Mens' : e_dtt_ab_mens,
    'Dtt Ecart Ab Mens Etud' : e_dtt_ab_mens_etud,
    'Agence Ecart support BSC' : e_agence_support_b,
    'Agence Ecart support CSC' : e_agence_support_c,
    'Agence Ecart voyage' : e_agence_voyage,
    'Agence Ecart Ab Hebdo' : e_agence_ab_hebdo,
    'Agence Ecart Ab Mens' : e_agence_ab_mens,
    'Agence Ecart Ab Mens Etud' : e_agence_ab_mens_etud,
    'Depo Ecart support BSC' : e_depo_support_b,
    'Depo Ecart support CSC' : e_depo_support_c,
    'Depo Ecart voyage' : e_depo_voyage,
    'Depo Ecart Ab Hebdo' : e_depo_ab_hebdo,
    'Depo Ecart Mens' : e_depo_ab_mens,
    'Depo Ecart Mens Etud' : e_depo_ab_mens_etud,
    'PV Ecart support BSC' : e_pv_support_b,
    'PV Ecart support voyage' : e_pv_voyage
}

#file generation
result = pd.DataFrame(data = d)
result.to_excel('Ecarts du 04 au 10 Mars 2020.xlsx',index=False)
print("file generated !")
# Out:
# Index(['Date', 'Quantité support', 'Quantité chargement', 'Ab Hébdo.',
#        'Ab Mens', 'Ab Mens Etud.', 'Support BSC', 'Support CSC', 'Voyage',
#        'Ab Hébdo..1', 'Ab Mens.1', 'Ab Mens Etud..1', 'Support BSC.1',
#        'Support CSC.1', 'Voyage.1', 'Ab Hébdo..2', 'Ab Mens.2',
#        'Ab Mens Etud..2', 'Support BSC.2', 'Voyage.2', 'Montant Support',
#        'Montant chargement', 'Ab Hébdo..3', 'Ab Mens.3', 'Ab Mens Etud..3',
#        'Bancaire dtts', 'Support BSC.3', 'Support CSC.2', 'Voyage.3',
#        'Ab Hébdo..4', 'Ab Mens.4', 'Ab Mens Etud..4', 'Bancaire agences',
#        'Support BSC.4', 'Support CSC.3', 'Voyage.4', 'Ab Hébdo..5',
#        'Ab Mens.5', 'Ab Mens Etud..5', 'Support BSC.5', 'Voyage.5',
#        'Unnamed: 41'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ca_dtt_support'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-8b9f107cdd05> in <module>
#      60 #gabs calculation
#      61
# ---> 62 e_dtt_support = data[ca_columns[0]] - (data[v_columns[0]]*2)
#      63 e_dtt_charge = data[ca_columns[1]] - (data[v_columns[1]]*6)
#      64 e_dtt_ab_hebdo = data[ca_columns[2]] - (data[v_columns[2]]*60)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'ca_dtt_support'

# %%
import pandas as pd

#files 2020 - 10,21,22
columns = ['0','date','v_dtt_qte_support','v_dtt_qte_charge','v_dtt_ab_hebdo','v_dtt_ab_mens',\
                                            'v_dtt_ab_mens_etud','v_agence_support_b','v_agence_support_c','v_agence_voyage',\
                                            'v_agence_ab_hebdo','v_agence_ab_mens',\
                                            'v_agence_ab_mens_etud','v_depo_support_b','v_depo_support_c','v_depo_voyage',\
                                            'v_depo_ab_hebdo','v_depo_ab_mens','v_depo_ab_mens_etud',\
                                            'v_pv_support_b','v_pv_voyage',\
                                            'ca_dtt_support','ca_dtt_charge','ca_dtt_ab_hebdo','ca_dtt_ab_mens',\
                                            'ca_dtt_ab_mens_etud','ca_dtt_banque',\
                                            'ca_agence_support_b','ca_agence_support_c','ca_agence_voyage',\
                                            'ca_agence_ab_hebdo','ca_agence_ab_mens',\
                                            'ca_agence_ab_mens_etud','ca_agence_banque',\
                                            'ca_depo_support_b','ca_depo_support_c','ca_depo_voyage',\
                                            'ca_depo_ab_hebdo','ca_depo_ab_mens','ca_depo_ab_mens_etud',\
                                            'ca_pv_support_b','ca_pv_voyage','rembours_banque','total']

v_columns = ['v_dtt_qte_support','v_dtt_qte_charge','v_dtt_ab_hebdo','v_dtt_ab_mens',\
                                            'v_dtt_ab_mens_etud','v_agence_support_b','v_agence_support_c','v_agence_voyage',\
                                            'v_agence_ab_hebdo','v_agence_ab_mens',\
                                            'v_agence_ab_mens_etud','v_depo_support_b','v_depo_support_c','v_depo_voyage',\
                                            'v_depo_ab_hebdo','v_depo_ab_mens','v_depo_ab_mens_etud',\
                                            'v_pv_support_b','v_pv_voyage']
ca_columns = ['ca_dtt_support','ca_dtt_charge','ca_dtt_ab_hebdo','ca_dtt_ab_mens',\
                                            'ca_dtt_ab_mens_etud','ca_agence_support_b','ca_agence_support_c','ca_agence_voyage',\
                                            'ca_agence_ab_hebdo','ca_agence_ab_mens',\
                                            'ca_agence_ab_mens_etud',\
                                            'ca_depo_support_b','ca_depo_support_c','ca_depo_voyage',\
                                            'ca_depo_ab_hebdo','ca_depo_ab_mens','ca_depo_ab_mens_etud',\
                                            'ca_pv_support_b','ca_pv_voyage']


#get the file
file = "10-Consolidation recette du 18 au 24 Mars 2020.xlsx"
data = pd.read_excel(file, header=11,names=columns, dtype={'date' : str}) 
#data = pd.read_excel(file, header=11) 


#lists initialization
e_dtt_support = []
e_dtt_charge = []
e_dtt_ab_hebdo = []
e_dtt_ab_mens = []
e_dtt_ab_mens_etud = []
e_agence_support_b = []
e_agence_support_c = []
e_agence_voyage = []
e_agence_ab_hebdo = []
e_agence_ab_mens = []
e_agence_ab_mens_etud = []
e_depo_support_b = []
e_depo_support_c = []
e_depo_voyage = []
e_depo_ab_hebdo = []
e_depo_ab_mens = []
e_depo_ab_mens_etud = []
e_pv_support_b = []
e_pv_voyage = []

#gabs calculation

e_dtt_support = data[ca_columns[0]] - (data[v_columns[0]]*2)
e_dtt_charge = data[ca_columns[1]] - (data[v_columns[1]]*6)
e_dtt_ab_hebdo = data[ca_columns[2]] - (data[v_columns[2]]*60)
e_dtt_ab_mens = data[ca_columns[3]] - (data[v_columns[3]]*230)
e_dtt_ab_mens_etud = data[ca_columns[4]] - (data[v_columns[4]]*150)
e_agence_support_b = data[ca_columns[5]] - (data[v_columns[5]]*2)
e_agence_support_c = data[ca_columns[6]] - (data[v_columns[6]]*15)
e_agence_voyage = data[ca_columns[7]] - (data[v_columns[7]]*6)
e_agence_ab_hebdo = data[ca_columns[8]] - (data[v_columns[8]]*60)
e_agence_ab_mens = data[ca_columns[9]] - (data[v_columns[9]]*230)
e_agence_ab_mens_etud = data[ca_columns[10]] - (data[v_columns[10]]*150)
e_depo_support_b = data[ca_columns[11]] - (data[v_columns[11]]*2)
e_depo_support_c = data[ca_columns[12]] - (data[v_columns[12]]*15)
e_depo_voyage = data[ca_columns[13]] - (data[v_columns[13]]*6)
e_depo_ab_hebdo = data[ca_columns[14]] - (data[v_columns[14]]*60)
e_depo_ab_mens = data[ca_columns[15]] - (data[v_columns[15]]*230)
e_depo_ab_mens_etud = data[ca_columns[16]] - (data[v_columns[16]]*150)
e_pv_support_b = data[ca_columns[17]] - (data[v_columns[17]]*2)
e_pv_voyage = data[ca_columns[18]] - (data[v_columns[18]]*6)

#dataframe making

d = {
    'Date' : data['date'],
    'Dtt Ecart support' : e_dtt_support,
    'Dtt chargement' : e_dtt_charge,
    'Dtt Ecart Ab Hebdo' : e_dtt_ab_hebdo,
    'Dtt Ecart Ab Mens' : e_dtt_ab_mens,
    'Dtt Ecart Ab Mens Etud' : e_dtt_ab_mens_etud,
    'Agence Ecart support BSC' : e_agence_support_b,
    'Agence Ecart support CSC' : e_agence_support_c,
    'Agence Ecart voyage' : e_agence_voyage,
    'Agence Ecart Ab Hebdo' : e_agence_ab_hebdo,
    'Agence Ecart Ab Mens' : e_agence_ab_mens,
    'Agence Ecart Ab Mens Etud' : e_agence_ab_mens_etud,
    'Depo Ecart support BSC' : e_depo_support_b,
    'Depo Ecart support CSC' : e_depo_support_c,
    'Depo Ecart voyage' : e_depo_voyage,
    'Depo Ecart Ab Hebdo' : e_depo_ab_hebdo,
    'Depo Ecart Mens' : e_depo_ab_mens,
    'Depo Ecart Mens Etud' : e_depo_ab_mens_etud,
    'PV Ecart support BSC' : e_pv_support_b,
    'PV Ecart support voyage' : e_pv_voyage
}

#file generation
result = pd.DataFrame(data = d)
result.to_excel('Ecarts du 18 au 24 Mars 2020.xlsx',index=False,)
print("file generated !")
# Out:
# file generated !

# %%
#consolidations new method for one file
import pandas as pd
from datetime import date, datetime, timedelta

errors = []


try:
    file = "C:/Users/ohoummi/Desktop/Oumnia/Rapport H recette 2021/Consolidation recettes Transport du 06 01 2021 au 12 01 2021.xlsx"
    data = pd.read_excel(file, header=11) 

    if list(data.columns)[0]=="Unnamed: 0" :
        data = data.drop(columns = ["Unnamed: 0"])

    print(data)    
    columns = ['date','v_dtt_support','v_dtt_charge','v_dtt_ab_hebdo','v_dtt_ab_mens',\
                                        'v_dtt_ab_mens_etud','v_agence_support_b','v_agence_support_c','v_agence_voyage',\
                                        'v_agence_ab_hebdo','v_agence_ab_mens',\
                                        'v_agence_ab_mens_etud','v_depo_support_b','v_depo_support_c','v_depo_voyage',\
                                        'v_depo_ab_hebdo','v_depo_ab_mens','v_depo_ab_mens_etud',\
                                        'v_pv_support_b','v_pv_voyage',\
                                        'ca_dtt_support','ca_dtt_charge','ca_dtt_ab_hebdo','ca_dtt_ab_mens',\
                                        'ca_dtt_ab_mens_etud','ca_dtt_banque',\
                                        'ca_agence_support_b','ca_agence_support_c','ca_agence_voyage',\
                                        'ca_agence_ab_hebdo','ca_agence_ab_mens',\
                                        'ca_agence_ab_mens_etud','ca_agence_banque',\
                                        'ca_depo_support_b','ca_depo_support_c','ca_depo_voyage',\
                                        'ca_depo_ab_hebdo','ca_depo_ab_mens','ca_depo_ab_mens_etud',\
                                        'ca_pv_support_b','ca_pv_voyage','rembours_banque','total']


    #get the file
    data = pd.read_excel(file, header=11,names=columns, dtype={'date' : str}) 

    #lists initialization
    e_dtt_support = []
    e_dtt_charge = []
    e_dtt_ab_hebdo = []
    e_dtt_ab_mens = []
    e_dtt_ab_mens_etud = []
    e_agence_support_b = []
    e_agence_support_c = []
    e_agence_voyage = []
    e_agence_ab_hebdo = []
    e_agence_ab_mens = []
    e_agence_ab_mens_etud = []
    e_depo_support_b = []
    e_depo_support_c = []
    e_depo_voyage = []
    e_depo_ab_hebdo = []
    e_depo_ab_mens = []
    e_depo_ab_mens_etud = []
    e_pv_support_b = []
    e_pv_voyage = []

    #gabs calculation
    e_dtt_support = data['ca_dtt_support'] - (data['v_dtt_support']*2)
    e_dtt_charge = data['ca_dtt_charge'] - (data['v_dtt_charge']*6)
    e_dtt_ab_hebdo = data['ca_dtt_ab_hebdo'] - (data['v_dtt_ab_hebdo']*60)
    e_dtt_ab_mens = data['ca_dtt_ab_mens'] - (data['v_dtt_ab_mens']*230)
    e_dtt_ab_mens_etud = data['ca_dtt_ab_mens_etud'] - (data['v_dtt_ab_mens_etud']*150)
    e_agence_support_b = data['ca_agence_support_b'] - (data['v_agence_support_b']*2)
    e_agence_support_c = data['ca_agence_support_c'] - (data['v_agence_support_c']*15)
    e_agence_voyage = data['ca_agence_voyage'] - (data['v_agence_voyage']*6)
    e_agence_ab_hebdo = data['ca_agence_ab_hebdo'] - (data['v_agence_ab_hebdo']*60)
    e_agence_ab_mens = data['ca_agence_ab_mens'] - (data['v_agence_ab_mens']*230)
    e_agence_ab_mens_etud = data['ca_agence_ab_mens_etud'] - (data['v_agence_ab_mens_etud']*150)
    e_depo_support_b = data['ca_depo_support_b'] - (data['v_depo_support_b']*2)
    e_depo_support_c = data['ca_depo_support_c'] - (data['v_depo_support_c']*15)
    e_depo_voyage = data['ca_depo_voyage'] - (data['v_depo_voyage']*6)
    e_depo_ab_hebdo = data['ca_depo_ab_hebdo'] - (data['v_depo_ab_hebdo']*60)
    e_depo_ab_mens = data['ca_depo_ab_mens'] - (data['v_depo_ab_mens']*230)
    e_depo_ab_mens_etud = data['ca_depo_ab_mens_etud'] - (data['v_depo_ab_mens_etud']*150)
    e_pv_support_b = data['ca_pv_support_b'] - (data['v_pv_support_b']*2)
    e_pv_voyage = data['ca_pv_voyage'] - (data['v_pv_voyage']*6)

    #print(data)
    #dataframe making

    d = {
        'Date' : data['date'],
        'Dtt Ecart support' : e_dtt_support,
        'Dtt chargement' : e_dtt_charge,
        'Dtt Ecart Ab Hebdo' : e_dtt_ab_hebdo,
        'Dtt Ecart Ab Mens' : e_dtt_ab_mens,
        'Dtt Ecart Ab Mens Etud' : e_dtt_ab_mens_etud,
        'Agence Ecart support BSC' : e_agence_support_b,
        'Agence Ecart support CSC' : e_agence_support_c,
        'Agence Ecart voyage' : e_agence_voyage,
        'Agence Ecart Ab Hebdo' : e_agence_ab_hebdo,
        'Agence Ecart Ab Mens' : e_agence_ab_mens,
        'Agence Ecart Ab Mens Etud' : e_agence_ab_mens_etud,
        'Depo Ecart support BSC' : e_depo_support_b,
        'Depo Ecart support CSC' : e_depo_support_c,
        'Depo Ecart voyage' : e_depo_voyage,
        'Depo Ecart Ab Hebdo' : e_depo_ab_hebdo,
        'Depo Ecart Mens' : e_depo_ab_mens,
        'Depo Ecart Mens Etud' : e_depo_ab_mens_etud,
        'PV Ecart support BSC' : e_pv_support_b,
        'PV Ecart support voyage' : e_pv_voyage
    }

    #file generation
    result = pd.DataFrame(data = d)
    #result.to_excel('C:/Users/ohoummi/Desktop/Oumnia/Rapport H recette 2021/Ecart recettes Transport du 06 01 2021 au 12 01 2021.xlsx',index=False)
    print("file generated (unnamed)!")
    #for i in ecarts print if ecart diff de 0

except Exception as e :
    errors.append(e)
    #print(i)

# %%
import pandas as pd
from datetime import date, datetime, timedelta

#files 2020 - 09,10,11,12,16,18,20,21,22,23,24,25,26,27...42 old 
errors = []

#prepare date

def datespan(startDate, endDate, delta=timedelta(days=1)):
    currentDate = startDate
    while currentDate < endDate:
        yield currentDate
        currentDate += delta

weeks = []    
day_start = []
day_end = []

for day in datespan(date(2020, 1, 1), date(2020, 12, 31), delta=timedelta(days=7)):

    day_start.append(day.strftime("%d-%m-%Y"))
    #print(day.strftime("%d-%m-%Y"))

for day in datespan(date(2020, 1, 7), date(2020, 12, 31), delta=timedelta(days=7)):

    day_end.append(day.strftime("%d-%m-%Y"))
    #print(day.strftime("%d-%m-%Y"))

#print(day_end)
for i in range(0,len(day_end)):
    weeks.append("du "+day_start[i]+" au "+day_end[i])

for i in weeks :
    try:
        file = "Consolidation recette transport "+i+".xlsx"
        data = pd.read_excel(file, header=11) 
        if len(data.columns) == 44 :

            columns = ['0','date','v_dtt_support','v_dtt_charge','v_dtt_ab_hebdo','v_dtt_ab_mens',\
                                                'v_dtt_ab_mens_etud','v_agence_support_b','v_agence_support_c','v_agence_voyage',\
                                                'v_agence_ab_hebdo','v_agence_ab_mens',\
                                                'v_agence_ab_mens_etud','v_depo_support_b','v_depo_support_c','v_depo_voyage',\
                                                'v_depo_ab_hebdo','v_depo_ab_mens','v_depo_ab_mens_etud',\
                                                'v_pv_support_b','v_pv_voyage',\
                                                'ca_dtt_support','ca_dtt_charge','ca_dtt_ab_hebdo','ca_dtt_ab_mens',\
                                                'ca_dtt_ab_mens_etud','ca_dtt_banque',\
                                                'ca_agence_support_b','ca_agence_support_c','ca_agence_voyage',\
                                                'ca_agence_ab_hebdo','ca_agence_ab_mens',\
                                                'ca_agence_ab_mens_etud','ca_agence_banque',\
                                                'ca_depo_support_b','ca_depo_support_c','ca_depo_voyage',\
                                                'ca_depo_ab_hebdo','ca_depo_ab_mens','ca_depo_ab_mens_etud',\
                                                'ca_pv_support_b','ca_pv_voyage','rembours_banque','total']


            #get the file
            data = pd.read_excel(file, header=11,names=columns, dtype={'date' : str}) 


            #lists initialization
            e_dtt_support = []
            e_dtt_charge = []
            e_dtt_ab_hebdo = []
            e_dtt_ab_mens = []
            e_dtt_ab_mens_etud = []
            e_agence_support_b = []
            e_agence_support_c = []
            e_agence_voyage = []
            e_agence_ab_hebdo = []
            e_agence_ab_mens = []
            e_agence_ab_mens_etud = []
            e_depo_support_b = []
            e_depo_support_c = []
            e_depo_voyage = []
            e_depo_ab_hebdo = []
            e_depo_ab_mens = []
            e_depo_ab_mens_etud = []
            e_pv_support_b = []
            e_pv_voyage = []

            #gabs calculation
            e_dtt_support = data['ca_dtt_support'] - (data['v_dtt_support']*2)
            e_dtt_charge = data['ca_dtt_charge'] - (data['v_dtt_charge']*6)
            e_dtt_ab_hebdo = data['ca_dtt_ab_hebdo'] - (data['v_dtt_ab_hebdo']*60)
            e_dtt_ab_mens = data['ca_dtt_ab_mens'] - (data['v_dtt_ab_mens']*230)
            e_dtt_ab_mens_etud = data['ca_dtt_ab_mens_etud'] - (data['v_dtt_ab_mens_etud']*150)
            e_agence_support_b = data['ca_agence_support_b'] - (data['v_agence_support_b']*2)
            e_agence_support_c = data['ca_agence_support_c'] - (data['v_agence_support_c']*15)
            e_agence_voyage = data['ca_agence_voyage'] - (data['v_agence_voyage']*6)
            e_agence_ab_hebdo = data['ca_agence_ab_hebdo'] - (data['v_agence_ab_hebdo']*60)
            e_agence_ab_mens = data['ca_agence_ab_mens'] - (data['v_agence_ab_mens']*230)
            e_agence_ab_mens_etud = data['ca_agence_ab_mens_etud'] - (data['v_agence_ab_mens_etud']*150)
            e_depo_support_b = data['ca_depo_support_b'] - (data['v_depo_support_b']*2)
            e_depo_support_c = data['ca_depo_support_c'] - (data['v_depo_support_c']*15)
            e_depo_voyage = data['ca_depo_voyage'] - (data['v_depo_voyage']*6)
            e_depo_ab_hebdo = data['ca_depo_ab_hebdo'] - (data['v_depo_ab_hebdo']*60)
            e_depo_ab_mens = data['ca_depo_ab_mens'] - (data['v_depo_ab_mens']*230)
            e_depo_ab_mens_etud = data['ca_depo_ab_mens_etud'] - (data['v_depo_ab_mens_etud']*150)
            e_pv_support_b = data['ca_pv_support_b'] - (data['v_pv_support_b']*2)
            e_pv_voyage = data['ca_pv_voyage'] - (data['v_pv_voyage']*6)

            #print(data)
            #dataframe making

            d = {
                'Date' : data['date'],
                'Dtt Ecart support' : e_dtt_support,
                'Dtt chargement' : e_dtt_charge,
                'Dtt Ecart Ab Hebdo' : e_dtt_ab_hebdo,
                'Dtt Ecart Ab Mens' : e_dtt_ab_mens,
                'Dtt Ecart Ab Mens Etud' : e_dtt_ab_mens_etud,
                'Agence Ecart support BSC' : e_agence_support_b,
                'Agence Ecart support CSC' : e_agence_support_c,
                'Agence Ecart voyage' : e_agence_voyage,
                'Agence Ecart Ab Hebdo' : e_agence_ab_hebdo,
                'Agence Ecart Ab Mens' : e_agence_ab_mens,
                'Agence Ecart Ab Mens Etud' : e_agence_ab_mens_etud,
                'Depo Ecart support BSC' : e_depo_support_b,
                'Depo Ecart support CSC' : e_depo_support_c,
                'Depo Ecart voyage' : e_depo_voyage,
                'Depo Ecart Ab Hebdo' : e_depo_ab_hebdo,
                'Depo Ecart Mens' : e_depo_ab_mens,
                'Depo Ecart Mens Etud' : e_depo_ab_mens_etud,
                'PV Ecart support BSC' : e_pv_support_b,
                'PV Ecart support voyage' : e_pv_voyage
            }

            #file generation
            result = pd.DataFrame(data = d)
            result.to_excel('Ecart '+i+'.xlsx',index=False)
            print("file generated !")

        elif len(data.columns) == 42 :    
            columns = ['date','v_dtt_support','v_dtt_charge','v_dtt_ab_hebdo','v_dtt_ab_mens',\
                                                        'v_dtt_ab_mens_etud','v_agence_support_b','v_agence_support_c','v_agence_voyage',\
                                                        'v_agence_ab_hebdo','v_agence_ab_mens',\
                                                        'v_agence_ab_mens_etud','v_depo_support_b','v_depo_support_c','v_depo_voyage',\
                                                        'v_depo_ab_hebdo','v_depo_ab_mens','v_depo_ab_mens_etud',\
                                                        'v_pv_support_b','v_pv_voyage',\
                                                        'ca_dtt_support','ca_dtt_charge','ca_dtt_ab_hebdo','ca_dtt_ab_mens',\
                                                        'ca_dtt_ab_mens_etud','ca_dtt_banque',\
                                                        'ca_agence_support_b','ca_agence_support_c','ca_agence_voyage',\
                                                        'ca_agence_ab_hebdo','ca_agence_ab_mens',\
                                                        'ca_agence_ab_mens_etud','ca_agence_banque',\
                                                        'ca_depo_support_b','ca_depo_support_c','ca_depo_voyage',\
                                                        'ca_depo_ab_hebdo','ca_depo_ab_mens','ca_depo_ab_mens_etud',\
                                                        'ca_pv_support_b','ca_pv_voyage','total']

            data = pd.read_excel(file, header=11,names=columns, dtype={'date' : str}) 
            print(i)
            print(data)
            #lists initialization
            e_dtt_support = []
            e_dtt_charge = []
            e_dtt_ab_hebdo = []
            e_dtt_ab_mens = []
            e_dtt_ab_mens_etud = []
            e_agence_support_b = []
            e_agence_support_c = []
            e_agence_voyage = []
            e_agence_ab_hebdo = []
            e_agence_ab_mens = []
            e_agence_ab_mens_etud = []
            e_depo_support_b = []
            e_depo_support_c = []
            e_depo_voyage = []
            e_depo_ab_hebdo = []
            e_depo_ab_mens = []
            e_depo_ab_mens_etud = []
            e_pv_support_b = []
            e_pv_voyage = []

            #gabs calculation
            e_dtt_support = data['ca_dtt_support'] - (data['v_dtt_support']*2)
            e_dtt_charge = data['ca_dtt_charge'] - (data['v_dtt_charge']*6)
            e_dtt_ab_hebdo = data['ca_dtt_ab_hebdo'] - (data['v_dtt_ab_hebdo']*60)
            e_dtt_ab_mens = data['ca_dtt_ab_mens'] - (data['v_dtt_ab_mens']*230)
            e_dtt_ab_mens_etud = data['ca_dtt_ab_mens_etud'] - (data['v_dtt_ab_mens_etud']*150)
            e_agence_support_b = data['ca_agence_support_b'] - (data['v_agence_support_b']*2)
            e_agence_support_c = data['ca_agence_support_c'] - (data['v_agence_support_c']*15)
            e_agence_voyage = data['ca_agence_voyage'] - (data['v_agence_voyage']*6)
            e_agence_ab_hebdo = data['ca_agence_ab_hebdo'] - (data['v_agence_ab_hebdo']*60)
            e_agence_ab_mens = data['ca_agence_ab_mens'] - (data['v_agence_ab_mens']*230)
            e_agence_ab_mens_etud = data['ca_agence_ab_mens_etud'] - (data['v_agence_ab_mens_etud']*150)
            e_depo_support_b = data['ca_depo_support_b'] - (data['v_depo_support_b']*2)
            e_depo_support_c = data['ca_depo_support_c'] - (data['v_depo_support_c']*15)
            e_depo_voyage = data['ca_depo_voyage'] - (data['v_depo_voyage']*6)
            e_depo_ab_hebdo = data['ca_depo_ab_hebdo'] - (data['v_depo_ab_hebdo']*60)
            e_depo_ab_mens = data['ca_depo_ab_mens'] - (data['v_depo_ab_mens']*230)
            e_depo_ab_mens_etud = data['ca_depo_ab_mens_etud'] - (data['v_depo_ab_mens_etud']*150)
            e_pv_support_b = data['ca_pv_support_b'] - (data['v_pv_support_b']*2)
            e_pv_voyage = data['ca_pv_voyage'] - (data['v_pv_voyage']*6)

            #dataframe making

            d = {
                'Date' : data['date'],
                'Dtt Ecart support' : e_dtt_support,
                'Dtt chargement' : e_dtt_charge,
                'Dtt Ecart Ab Hebdo' : e_dtt_ab_hebdo,
                'Dtt Ecart Ab Mens' : e_dtt_ab_mens,
                'Dtt Ecart Ab Mens Etud' : e_dtt_ab_mens_etud,
                'Agence Ecart support BSC' : e_agence_support_b,
                'Agence Ecart support CSC' : e_agence_support_c,
                'Agence Ecart voyage' : e_agence_voyage,
                'Agence Ecart Ab Hebdo' : e_agence_ab_hebdo,
                'Agence Ecart Ab Mens' : e_agence_ab_mens,
                'Agence Ecart Ab Mens Etud' : e_agence_ab_mens_etud,
                'Depo Ecart support BSC' : e_depo_support_b,
                'Depo Ecart support CSC' : e_depo_support_c,
                'Depo Ecart voyage' : e_depo_voyage,
                'Depo Ecart Ab Hebdo' : e_depo_ab_hebdo,
                'Depo Ecart Mens' : e_depo_ab_mens,
                'Depo Ecart Mens Etud' : e_depo_ab_mens_etud,
                'PV Ecart support BSC' : e_pv_support_b,
                'PV Ecart support voyage' : e_pv_voyage
            }

            #file generation
            result = pd.DataFrame(data = d)
            result.to_excel('Ecart '+i+'.xlsx',index=False)
            print("file generated !")
    except Exception as e :
        errors.append(e)
        print(i)
        continue
